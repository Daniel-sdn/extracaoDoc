# %% [markdown]
# # OCR Demo: Full vs. Partial OCR of Pages
# In v1.19.1 of PyMuPDF there are two choices of OCRing a document page: **_full_** or **_partial_**. In both cases, a `TextPage` object will be created - available for text extractions and text searches as usual. All these text processing methods have been extended with the new parameter `textpage` to allow referencing the OCR result.
# * A **_full OCR_** makes a photo of the page with the desired resolution and interprets it.
#    - All **_visible text_** on the page will be OCRed.
#    - All text will have Tesseract's "GlyphlessFont".
#    - May take around 2 seonds - depending on text amount and DPI.
# * A **_partial OCR_** interprets only the images displayed by the page.
#    - The DPI parameter is not needed, because the original images are OCRed.
#    - Text will be a **_mixture of normal and OCR text_**. Normal text retains its properties.
#    - Can be much faster than a full OCR.

# %%
import fitz

if tuple(map(int, fitz.VersionBind.split("."))) < (1, 19, 1):
    raise ValueError("Need at least v1.19.1 of PyMuPDF")

# eample PDF contains normal text and two overlapping images
doc = fitz.open(r".\PyMuPDF_examples\272519EC-959B-4460-BBE6-D80D272B9ACD.PDF")
page = doc[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7045/327864397.py in ?()
#       3 if tuple(map(int, fitz.VersionBind.split("."))) < (1, 19, 1):
#       4     raise ValueError("Need at least v1.19.1 of PyMuPDF")
#       5
#       6 # eample PDF contains normal text and two overlapping images
# ----> 7 doc = fitz.open(r".\PyMuPDF_examples\272519EC-959B-4460-BBE6-D80D272B9ACD.PDF")
#       8 page = doc[0]
#
# ~/miniconda3/envs/tables-detr/lib/python3.10/site-packages/fitz/fitz.py in ?(self, filename, stream, filetype, rect, width, height, fontsize)
#    3949
#    3950         if from_file:
#    3951             if not os.path.exists(filename):
#    3952                 msg = f"no such file: '{filename}'"
# -> 3953                 raise FileNotFoundError(msg)
#    3954             elif not os.path.isfile(filename):
#    3955                 msg = f"'{filename}' is no file"
#    3956                 raise FileDataError(msg)
#
# FileNotFoundError: no such file: '.\PyMuPDF_examples\272519EC-959B-4460-BBE6-D80D272B9ACD.PDF'

# %% [markdown]
# ## Full Page OCR
# First make a **_full page OCR_**. Please take a look at the PDF and note the two little text lines. They are contained in a separate, non-transparent image, which covers some text of the larger image underneath it.

# %%
# make the TextPage object. It does all the OCR.
full_tp = page.get_textpage_ocr(flags=0, dpi=300, full=True, language='por', tessdata="C:\\Program Files\\Tesseract-OCR\\tessdata")

# now look at what we have got
print(page.get_text(textpage=full_tp))
# Out:
# cd
# Número da Nota:
# ERRME
# PREFEITURA MUNICIPAL DE MESQUITA
# 2023113
# Vi
# A
# Vé
# Competência:
# ENE” É
# SECRETARIA MUNICIPAL DE FAZENDA
# JULHO/2023
# DS VA
# NOTA FISCAL DE SERVIÇO ELETRÔNICA- NFS
# Data e Hora de Emisssão:
# Y) AO,44::
# ç
# j
# Se
# 01/08/2023 03:32:41
# BR mes quer 1º
# RPS Nº: 1386 SERIE: 1
# | EMISSÃO: 01/08/2023
# Código de Verificação:
# C64B104C7
# PRESTADOR DE SERVIÇOS
# CPF/CNPJ:
# Inscrição Municipal:
# 15.064.270/0001-33
# 5000545
# Telefone:
# Inscrição Estadual:
# (21) 3848-0080
# Nome/Razão Social:
# MODERNIZACAO PUBLICA E INFORMATICA LTDA
# UOGERNIZAÇÃO
# Nome Fantasia: Modernização Pública
# Publica
# Endereço:
# RUA PREFEITO JOSE MONTES PAIXAO, 1708 SOBRADO CENTRO MESQUITA/RJ CEP: 26553-161
# E-mail:
# vm.direcao(Dyahoo.com.br
# TOMADOR DE SERVIÇOS
# CPF/CNPJ:
# Inscrição Municipal:
# 28.909.604/0001-74
# Telefone:
# Inscrição Estadual:
# Nome/Razão Social:
# PREF.MUN.DE SAO PEDRO DA ALDEIA
# Endereço:
# Rua Marques da Cruz, 61 CENTRO SAO PEDRO DA ALDEIA/RJ/RJ CEP: 28941-086
# E-mail:
# DISCRIMINAÇÃO DOS SERVIÇOS
# CESSAO DE LICENCIAMENTO DE USO DE SOLUCAO PARA SISTEMA INTEGRADO DE GESTAO PUBLICA CONTRATO 94/2022, PR
# OCESSO 6699/2022 NOTA FISCAL REFERENTE AO MES 07/2023
# - CREDITAR NO BANCO BRADESCO AG 6615 C/C 12311-0 OU BANCO DO BRASIL AG 1253-X C/C 125016-7 OU
# PIX: CNPJ 15.064.270/0001-33
# VALOR TOTAL DA NOTA: R$ 206.549,00
# CNAE - 6202300 - DESENVOLVIMENTO E LICENCIAMENTO DE PROGRAMAS DE COMPUTADOR CUSTOMIZÁVEIS
# Item da Lista de Serviços - 1.05 Licenciamento ou cessão de direito de uso de programas de computação.
# VALOR SERVIÇOS: VALOR
# DESC. INCOND.: BASE DE
# ALÍQUOTA:
# VALOR ISS:
# VALOR ISS
# DESC. COND.:
# DEDUÇÃO:
# CÁLCULO:
# RETIDO:
# R$ 206.549,00
# R$ 0,00
# R$ 0,00
# R$ 206.549,00
# 2,00%
# R$ 4.130,98
# R$ 0,00
# R$ 0,00
# VALOR PIS:
# VALOR COFINS:
# VALOR IR:
# VALOR INSS:
# VALOR CSLL:
# OUTRAS RETENÇÕES:
# VALOR LÍQUIDO:
# R$ 0,00
# R$ 0,00
# R$ 3.098,23
# R$ 0,00
# R$ 0,00
# R$ 0,00
# R$ 203.450,77
# DADOS COMPLEMENTARES
# OUTRAS INFORMAÇÕES/CRÍTICAS
# EXIGIBILIDADE ISS
# REGIME TRIBUTAÇÃO
# SIMPLES NACIONAL
# LOCAL PRESTAÇÃO
# LOCAL INCIDÊNCIA
# SERVIÇO
# EXIGÍVEL
# Sociedade Limitada
# Não
# SAO PEDRO DA ALDEIA/RJ
# MESQUITA/RJ
# Observação: LEI DA TRANSPARÊNCIA FISCAL NR. 12.741, DE 8 DE DEZEMBRO DE 2012.

# %% [markdown]
# Or blockwise output, getting rid of some of the unwanted linebreaks:

# %%
blocks = page.get_text("blocks", textpage=full_tp)
for b in blocks:
    print(b[4].replace("\n", " "))
# Out:
# cd Número da Nota: ERRME PREFEITURA MUNICIPAL DE MESQUITA 2023113 Vi A Vé Competência: ENE” É SECRETARIA MUNICIPAL DE FAZENDA JULHO/2023 DS VA NOTA FISCAL DE SERVIÇO ELETRÔNICA- NFS Data e Hora de Emisssão: Y) AO,44:: ç j Se 01/08/2023 03:32:41 BR mes quer 1º RPS Nº: 1386 SERIE: 1 | EMISSÃO: 01/08/2023 Código de Verificação: C64B104C7
# PRESTADOR DE SERVIÇOS
# CPF/CNPJ: Inscrição Municipal: 15.064.270/0001-33 5000545
# Telefone: Inscrição Estadual: (21) 3848-0080 Nome/Razão Social: MODERNIZACAO PUBLICA E INFORMATICA LTDA UOGERNIZAÇÃO Nome Fantasia: Modernização Pública Publica Endereço: RUA PREFEITO JOSE MONTES PAIXAO, 1708 SOBRADO CENTRO MESQUITA/RJ CEP: 26553-161 E-mail: vm.direcao(Dyahoo.com.br
# TOMADOR DE SERVIÇOS
# CPF/CNPJ: Inscrição Municipal: 28.909.604/0001-74
# Telefone: Inscrição Estadual:
# Nome/Razão Social: PREF.MUN.DE SAO PEDRO DA ALDEIA
# Endereço: Rua Marques da Cruz, 61 CENTRO SAO PEDRO DA ALDEIA/RJ/RJ CEP: 28941-086 E-mail:
# DISCRIMINAÇÃO DOS SERVIÇOS
# CESSAO DE LICENCIAMENTO DE USO DE SOLUCAO PARA SISTEMA INTEGRADO DE GESTAO PUBLICA CONTRATO 94/2022, PR OCESSO 6699/2022 NOTA FISCAL REFERENTE AO MES 07/2023
# - CREDITAR NO BANCO BRADESCO AG 6615 C/C 12311-0 OU BANCO DO BRASIL AG 1253-X C/C 125016-7 OU PIX: CNPJ 15.064.270/0001-33
# VALOR TOTAL DA NOTA: R$ 206.549,00
# CNAE - 6202300 - DESENVOLVIMENTO E LICENCIAMENTO DE PROGRAMAS DE COMPUTADOR CUSTOMIZÁVEIS
# Item da Lista de Serviços - 1.05 Licenciamento ou cessão de direito de uso de programas de computação.
# VALOR SERVIÇOS: VALOR DESC. INCOND.: BASE DE ALÍQUOTA: VALOR ISS: VALOR ISS DESC. COND.: DEDUÇÃO: CÁLCULO: RETIDO: R$ 206.549,00 R$ 0,00 R$ 0,00 R$ 206.549,00 2,00% R$ 4.130,98 R$ 0,00 R$ 0,00
# VALOR PIS: VALOR COFINS: VALOR IR: VALOR INSS: VALOR CSLL: OUTRAS RETENÇÕES: VALOR LÍQUIDO:
# R$ 0,00 R$ 0,00 R$ 3.098,23 R$ 0,00 R$ 0,00 R$ 0,00 R$ 203.450,77
# DADOS COMPLEMENTARES
# OUTRAS INFORMAÇÕES/CRÍTICAS
# EXIGIBILIDADE ISS REGIME TRIBUTAÇÃO SIMPLES NACIONAL LOCAL PRESTAÇÃO LOCAL INCIDÊNCIA SERVIÇO EXIGÍVEL Sociedade Limitada Não SAO PEDRO DA ALDEIA/RJ MESQUITA/RJ
# Observação: LEI DA TRANSPARÊNCIA FISCAL NR. 12.741, DE 8 DE DEZEMBRO DE 2012.

# %% [markdown]
# Not very impressive either way: the original text (last 4 lines) was detected ok, but text in the pictures looks quite garbled ... no surprise!
#
# > Please note, that the OCR process scans the page from top-left to bottom-right - which therefore also is the sequence of the extraction.
#
# This is what we get when looking at details of each text span:

# %%
for block in page.get_text("dict", textpage=full_tp)["blocks"]:
    for line in block["lines"]:
        for span in line["spans"]:
            bbox = fitz.Rect(span["bbox"]).irect  # just to make it short in the display
            print( span["font"], bbox, span["text"])
# Out:
# GlyphLessFont IRect(54, 48, 81, 53) cd
# GlyphLessFont IRect(489, 40, 525, 49) Número
# GlyphLessFont IRect(524, 40, 539, 49)  da
# GlyphLessFont IRect(538, 40, 565, 49)  Nota:
# GlyphLessFont IRect(47, 52, 87, 77) ERRME
# GlyphLessFont IRect(118, 52, 194, 77) PREFEITURA
# GlyphLessFont IRect(193, 52, 264, 77)  MUNICIPAL
# GlyphLessFont IRect(263, 52, 284, 77)  DE
# GlyphLessFont IRect(283, 52, 351, 77)  MESQUITA
# GlyphLessFont IRect(526, 52, 565, 77) 2023113
# GlyphLessFont IRect(37, 52, 45, 77) Vi
# GlyphLessFont IRect(60, 63, 76, 76) A
# GlyphLessFont IRect(91, 63, 94, 76) Vé
# GlyphLessFont IRect(516, 63, 566, 76) Competência:
# GlyphLessFont IRect(49, 75, 87, 99) ENE”
# GlyphLessFont IRect(86, 75, 96, 99)  É
# GlyphLessFont IRect(158, 75, 210, 99) SECRETARIA
# GlyphLessFont IRect(209, 75, 256, 99)  MUNICIPAL
# GlyphLessFont IRect(255, 75, 270, 99)  DE
# GlyphLessFont IRect(269, 75, 311, 99)  FAZENDA
# GlyphLessFont IRect(518, 75, 565, 99) JULHO/2023
# GlyphLessFont IRect(36, 75, 44, 99) DS
# GlyphLessFont IRect(43, 77, 65, 107)  VA
# GlyphLessFont IRect(139, 84, 162, 107) NOTA
# GlyphLessFont IRect(161, 84, 193, 107)  FISCAL
# GlyphLessFont IRect(192, 84, 244, 107)  DE SERVIÇO
# GlyphLessFont IRect(243, 84, 299, 107)  ELETRÔNICA
# GlyphLessFont IRect(300, 84, 304, 107) -
# GlyphLessFont IRect(303, 84, 322, 107)  NFS
# GlyphLessFont IRect(472, 84, 489, 107) Data
# GlyphLessFont IRect(488, 84, 496, 107)  e
# GlyphLessFont IRect(495, 84, 526, 107)  Hora de
# GlyphLessFont IRect(525, 84, 565, 107)  Emisssão:
# GlyphLessFont IRect(40, 84, 49, 107) Y)
# GlyphLessFont IRect(48, 79, 96, 118)  AO,44::
# GlyphLessFont IRect(232, 90, 238, 118) ç
# GlyphLessFont IRect(266, 90, 269, 118) j
# GlyphLessFont IRect(301, 90, 329, 118) Se
# GlyphLessFont IRect(491, 90, 530, 118) 01/08/2023
# GlyphLessFont IRect(529, 90, 564, 118)  03:32:41
# GlyphLessFont IRect(38, 90, 49, 118) BR
# GlyphLessFont IRect(48, 103, 66, 119)  mes
# GlyphLessFont IRect(65, 104, 82, 119)  quer
# GlyphLessFont IRect(81, 104, 97, 119)  1º
# GlyphLessFont IRect(148, 104, 164, 119) RPS
# GlyphLessFont IRect(163, 104, 177, 119)  Nº:
# GlyphLessFont IRect(176, 104, 197, 119)  1386
# GlyphLessFont IRect(196, 104, 226, 119)  SERIE:
# GlyphLessFont IRect(225, 104, 232, 119)  1
# GlyphLessFont IRect(235, 104, 237, 119) |
# GlyphLessFont IRect(236, 104, 279, 119)  EMISSÃO:
# GlyphLessFont IRect(278, 104, 321, 119)  01/08/2023
# GlyphLessFont IRect(485, 104, 510, 119) Código
# GlyphLessFont IRect(509, 104, 522, 119)  de
# GlyphLessFont IRect(521, 104, 566, 119)  Verificação:
# GlyphLessFont IRect(521, 120, 566, 128) C64B104C7
# GlyphLessFont IRect(217, 138, 292, 151) PRESTADOR
# GlyphLessFont IRect(291, 138, 312, 151)  DE
# GlyphLessFont IRect(311, 138, 377, 151)  SERVIÇOS
# GlyphLessFont IRect(27, 158, 73, 169) CPF/CNPJ:
# GlyphLessFont IRect(283, 158, 319, 169) Inscrição
# GlyphLessFont IRect(318, 158, 361, 169)  Municipal:
# GlyphLessFont IRect(35, 170, 115, 177) 15.064.270/0001-33
# GlyphLessFont IRect(290, 170, 325, 177) 5000545
# GlyphLessFont IRect(27, 180, 64, 192) Telefone:
# GlyphLessFont IRect(283, 180, 319, 192) Inscrição
# GlyphLessFont IRect(318, 180, 359, 192)  Estadual:
# GlyphLessFont IRect(34, 192, 51, 202) (21)
# GlyphLessFont IRect(50, 192, 96, 202)  3848-0080
# GlyphLessFont IRect(27, 203, 80, 211) Nome/Razão
# GlyphLessFont IRect(79, 203, 109, 211)  Social:
# GlyphLessFont IRect(35, 214, 109, 226) MODERNIZACAO
# GlyphLessFont IRect(108, 214, 152, 226)  PUBLICA
# GlyphLessFont IRect(151, 214, 160, 226)  E
# GlyphLessFont IRect(159, 214, 225, 226)  INFORMATICA
# GlyphLessFont IRect(224, 214, 252, 226)  LTDA
# GlyphLessFont IRect(504, 214, 551, 226) UOGERNIZAÇÃO
# GlyphLessFont IRect(27, 223, 51, 236) Nome
# GlyphLessFont IRect(50, 223, 90, 236)  Fantasia:
# GlyphLessFont IRect(89, 223, 155, 236)  Modernização
# GlyphLessFont IRect(154, 223, 190, 236)  Pública
# GlyphLessFont IRect(503, 223, 550, 236) Publica
# GlyphLessFont IRect(27, 239, 68, 248) Endereço:
# GlyphLessFont IRect(35, 249, 54, 259) RUA
# GlyphLessFont IRect(53, 249, 102, 259)  PREFEITO
# GlyphLessFont IRect(101, 249, 128, 259)  JOSE
# GlyphLessFont IRect(127, 249, 169, 259)  MONTES
# GlyphLessFont IRect(168, 249, 208, 259)  PAIXAO,
# GlyphLessFont IRect(207, 249, 231, 259)  1708
# GlyphLessFont IRect(230, 249, 279, 259)  SOBRADO
# GlyphLessFont IRect(278, 249, 320, 259)  CENTRO
# GlyphLessFont IRect(319, 249, 384, 259)  MESQUITA/RJ
# GlyphLessFont IRect(383, 249, 408, 259)  CEP:
# GlyphLessFont IRect(407, 249, 452, 259)  26553-161
# GlyphLessFont IRect(27, 261, 55, 269) E-mail:
# GlyphLessFont IRect(34, 272, 149, 282) vm.direcao(Dyahoo.com.br
# GlyphLessFont IRect(223, 292, 285, 305) TOMADOR
# GlyphLessFont IRect(284, 292, 305, 305)  DE
# GlyphLessFont IRect(304, 292, 371, 305)  SERVIÇOS
# GlyphLessFont IRect(27, 311, 73, 323) CPF/CNPJ:
# GlyphLessFont IRect(283, 311, 319, 323) Inscrição
# GlyphLessFont IRect(318, 311, 361, 323)  Municipal:
# GlyphLessFont IRect(34, 323, 115, 331) 28.909.604/0001-74
# GlyphLessFont IRect(27, 334, 64, 346) Telefone:
# GlyphLessFont IRect(283, 334, 319, 346) Inscrição
# GlyphLessFont IRect(318, 334, 359, 346)  Estadual:
# GlyphLessFont IRect(27, 357, 80, 365) Nome/Razão
# GlyphLessFont IRect(79, 357, 109, 365)  Social:
# GlyphLessFont IRect(35, 368, 96, 376) PREF.MUN.DE
# GlyphLessFont IRect(95, 368, 119, 376)  SAO
# GlyphLessFont IRect(118, 368, 153, 376)  PEDRO
# GlyphLessFont IRect(152, 368, 169, 376)  DA
# GlyphLessFont IRect(168, 368, 205, 376)  ALDEIA
# GlyphLessFont IRect(27, 380, 68, 389) Endereço:
# GlyphLessFont IRect(35, 391, 52, 400) Rua
# GlyphLessFont IRect(51, 391, 91, 400)  Marques
# GlyphLessFont IRect(90, 391, 104, 400)  da
# GlyphLessFont IRect(103, 391, 129, 400)  Cruz,
# GlyphLessFont IRect(128, 391, 140, 400)  61
# GlyphLessFont IRect(139, 391, 184, 400)  CENTRO
# GlyphLessFont IRect(183, 391, 207, 400)  SAO
# GlyphLessFont IRect(206, 391, 241, 400)  PEDRO
# GlyphLessFont IRect(240, 391, 257, 400)  DA
# GlyphLessFont IRect(256, 391, 320, 400)  ALDEIA/RJ/RJ
# GlyphLessFont IRect(319, 391, 344, 400)  CEP:
# GlyphLessFont IRect(343, 391, 390, 400)  28941-086
# GlyphLessFont IRect(27, 402, 55, 410) E-mail:
# GlyphLessFont IRect(202, 417, 299, 432) DISCRIMINAÇÃO
# GlyphLessFont IRect(298, 417, 328, 432)  DOS
# GlyphLessFont IRect(327, 417, 393, 432)  SERVIÇOS
# GlyphLessFont IRect(27, 443, 60, 451) CESSAO
# GlyphLessFont IRect(59, 443, 74, 451)  DE
# GlyphLessFont IRect(73, 443, 142, 451)  LICENCIAMENTO
# GlyphLessFont IRect(141, 443, 155, 451)  DE
# GlyphLessFont IRect(154, 443, 175, 451)  USO
# GlyphLessFont IRect(174, 443, 188, 451)  DE
# GlyphLessFont IRect(187, 443, 229, 451)  SOLUCAO
# GlyphLessFont IRect(228, 443, 254, 451)  PARA
# GlyphLessFont IRect(253, 443, 291, 451)  SISTEMA
# GlyphLessFont IRect(290, 443, 340, 451)  INTEGRADO
# GlyphLessFont IRect(339, 443, 354, 451)  DE
# GlyphLessFont IRect(353, 443, 389, 451)  GESTAO
# GlyphLessFont IRect(388, 443, 426, 451)  PUBLICA
# GlyphLessFont IRect(425, 443, 473, 451)  CONTRATO
# GlyphLessFont IRect(472, 443, 508, 451)  94/2022,
# GlyphLessFont IRect(507, 443, 522, 451)  PR
# GlyphLessFont IRect(27, 452, 61, 459) OCESSO
# GlyphLessFont IRect(60, 452, 101, 459)  6699/2022
# GlyphLessFont IRect(100, 452, 126, 459)  NOTA
# GlyphLessFont IRect(125, 452, 156, 459)  FISCAL
# GlyphLessFont IRect(155, 452, 206, 459)  REFERENTE
# GlyphLessFont IRect(205, 452, 220, 459)  AO
# GlyphLessFont IRect(219, 452, 240, 459)  MES
# GlyphLessFont IRect(239, 452, 271, 459)  07/2023
# GlyphLessFont IRect(27, 461, 30, 468) -
# GlyphLessFont IRect(29, 461, 75, 468)  CREDITAR
# GlyphLessFont IRect(74, 461, 89, 468)  NO
# GlyphLessFont IRect(88, 461, 167, 468)  BANCO BRADESCO
# GlyphLessFont IRect(166, 461, 181, 468)  AG
# GlyphLessFont IRect(180, 461, 201, 468)  6615
# GlyphLessFont IRect(200, 461, 217, 468)  C/C
# GlyphLessFont IRect(216, 461, 248, 468)  12311-0
# GlyphLessFont IRect(247, 461, 262, 468)  OU
# GlyphLessFont IRect(261, 461, 308, 468)  BANCO DO
# GlyphLessFont IRect(307, 461, 338, 468)  BRASIL
# GlyphLessFont IRect(337, 461, 352, 468)  AG
# GlyphLessFont IRect(351, 461, 380, 468)  1253-X
# GlyphLessFont IRect(379, 461, 396, 468)  C/C
# GlyphLessFont IRect(395, 461, 432, 468)  125016-7
# GlyphLessFont IRect(431, 461, 446, 468)  OU
# GlyphLessFont IRect(27, 470, 42, 477) PIX:
# GlyphLessFont IRect(41, 470, 65, 477)  CNPJ
# GlyphLessFont IRect(64, 470, 139, 477)  15.064.270/0001-33
# GlyphLessFont IRect(176, 528, 218, 540) VALOR
# GlyphLessFont IRect(217, 528, 261, 540)  TOTAL
# GlyphLessFont IRect(260, 528, 282, 540)  DA
# GlyphLessFont IRect(281, 528, 323, 540)  NOTA:
# GlyphLessFont IRect(322, 528, 341, 540)  R$
# GlyphLessFont IRect(340, 528, 404, 540)  206.549,00
# GlyphLessFont IRect(27, 547, 49, 556) CNAE
# GlyphLessFont IRect(48, 547, 54, 556)  -
# GlyphLessFont IRect(53, 547, 87, 556)  6202300
# GlyphLessFont IRect(86, 547, 92, 556)  -
# GlyphLessFont IRect(91, 547, 175, 556)  DESENVOLVIMENTO
# GlyphLessFont IRect(174, 547, 182, 556)  E
# GlyphLessFont IRect(181, 547, 250, 556)  LICENCIAMENTO
# GlyphLessFont IRect(249, 547, 263, 556)  DE
# GlyphLessFont IRect(262, 547, 318, 556)  PROGRAMAS
# GlyphLessFont IRect(317, 547, 331, 556)  DE
# GlyphLessFont IRect(330, 547, 391, 556)  COMPUTADOR
# GlyphLessFont IRect(390, 547, 458, 556)  CUSTOMIZÁVEIS
# GlyphLessFont IRect(27, 561, 42, 570) Item
# GlyphLessFont IRect(41, 561, 54, 570)  da
# GlyphLessFont IRect(53, 561, 73, 570)  Lista
# GlyphLessFont IRect(72, 561, 84, 570)  de
# GlyphLessFont IRect(83, 561, 117, 570)  Serviços
# GlyphLessFont IRect(116, 561, 122, 570)  -
# GlyphLessFont IRect(121, 561, 139, 570)  1.05
# GlyphLessFont IRect(138, 561, 194, 570)  Licenciamento
# GlyphLessFont IRect(193, 561, 206, 570)  ou
# GlyphLessFont IRect(205, 561, 234, 570)  cessão
# GlyphLessFont IRect(233, 561, 245, 570)  de
# GlyphLessFont IRect(244, 561, 269, 570)  direito
# GlyphLessFont IRect(268, 561, 280, 570)  de
# GlyphLessFont IRect(279, 561, 295, 570)  uso
# GlyphLessFont IRect(294, 561, 306, 570)  de
# GlyphLessFont IRect(305, 561, 346, 570)  programas
# GlyphLessFont IRect(345, 561, 358, 570)  de
# GlyphLessFont IRect(357, 561, 405, 570)  computação.
# GlyphLessFont IRect(84, 580, 108, 592) VALOR
# GlyphLessFont IRect(107, 580, 147, 592)  SERVIÇOS:
# GlyphLessFont IRect(146, 580, 176, 592)  VALOR
# GlyphLessFont IRect(213, 580, 234, 592) DESC.
# GlyphLessFont IRect(233, 580, 268, 592)  INCOND.:
# GlyphLessFont IRect(267, 580, 292, 592)  BASE
# GlyphLessFont IRect(291, 580, 304, 592)  DE
# GlyphLessFont IRect(336, 580, 373, 592) ALÍQUOTA:
# GlyphLessFont IRect(396, 580, 421, 592) VALOR
# GlyphLessFont IRect(420, 580, 435, 592)  ISS:
# GlyphLessFont IRect(457, 580, 481, 592) VALOR
# GlyphLessFont IRect(480, 580, 494, 592)  ISS
# GlyphLessFont IRect(516, 580, 537, 592) DESC.
# GlyphLessFont IRect(536, 580, 564, 592)  COND.:
# GlyphLessFont IRect(152, 591, 189, 602) DEDUÇÃO:
# GlyphLessFont IRect(273, 591, 309, 602) CÁLCULO:
# GlyphLessFont IRect(458, 591, 486, 602) RETIDO:
# GlyphLessFont IRect(84, 604, 93, 611) R$
# GlyphLessFont IRect(92, 604, 130, 611)  206.549,00
# GlyphLessFont IRect(152, 604, 161, 611) R$
# GlyphLessFont IRect(160, 604, 177, 611)  0,00
# GlyphLessFont IRect(213, 604, 222, 611) R$
# GlyphLessFont IRect(221, 604, 238, 611)  0,00
# GlyphLessFont IRect(274, 604, 283, 611) R$
# GlyphLessFont IRect(282, 604, 320, 611)  206.549,00
# GlyphLessFont IRect(336, 604, 358, 611) 2,00%
# GlyphLessFont IRect(397, 604, 406, 611) R$
# GlyphLessFont IRect(405, 604, 435, 611)  4.130,98
# GlyphLessFont IRect(458, 604, 467, 611) R$
# GlyphLessFont IRect(466, 604, 482, 611)  0,00
# GlyphLessFont IRect(516, 604, 525, 611) R$
# GlyphLessFont IRect(524, 604, 540, 611)  0,00
# GlyphLessFont IRect(84, 620, 111, 629) VALOR
# GlyphLessFont IRect(110, 620, 128, 629)  PIS:
# GlyphLessFont IRect(152, 620, 176, 629) VALOR
# GlyphLessFont IRect(175, 620, 206, 629)  COFINS:
# GlyphLessFont IRect(213, 620, 237, 629) VALOR
# GlyphLessFont IRect(236, 620, 248, 629)  IR:
# GlyphLessFont IRect(273, 620, 297, 629) VALOR
# GlyphLessFont IRect(296, 620, 318, 629)  INSS:
# GlyphLessFont IRect(336, 620, 360, 629) VALOR
# GlyphLessFont IRect(359, 620, 381, 629)  CSLL:
# GlyphLessFont IRect(396, 620, 426, 629) OUTRAS
# GlyphLessFont IRect(425, 620, 473, 629)  RETENÇÕES:
# GlyphLessFont IRect(516, 620, 540, 629) VALOR
# GlyphLessFont IRect(539, 620, 572, 629)  LÍQUIDO:
# GlyphLessFont IRect(84, 632, 93, 640) R$
# GlyphLessFont IRect(92, 632, 109, 640)  0,00
# GlyphLessFont IRect(152, 632, 161, 640) R$
# GlyphLessFont IRect(160, 632, 177, 640)  0,00
# GlyphLessFont IRect(213, 632, 222, 640) R$
# GlyphLessFont IRect(221, 632, 251, 640)  3.098,23
# GlyphLessFont IRect(274, 632, 283, 640) R$
# GlyphLessFont IRect(282, 632, 298, 640)  0,00
# GlyphLessFont IRect(336, 632, 345, 640) R$
# GlyphLessFont IRect(344, 632, 361, 640)  0,00
# GlyphLessFont IRect(397, 632, 406, 640) R$
# GlyphLessFont IRect(405, 632, 421, 640)  0,00
# GlyphLessFont IRect(516, 632, 525, 640) R$
# GlyphLessFont IRect(524, 632, 562, 640)  203.450,77
# GlyphLessFont IRect(215, 651, 380, 661) DADOS COMPLEMENTARES
# GlyphLessFont IRect(195, 691, 246, 706) OUTRAS
# GlyphLessFont IRect(245, 691, 399, 706)  INFORMAÇÕES/CRÍTICAS
# GlyphLessFont IRect(48, 714, 98, 723) EXIGIBILIDADE
# GlyphLessFont IRect(97, 714, 111, 723)  ISS
# GlyphLessFont IRect(147, 714, 174, 723) REGIME
# GlyphLessFont IRect(173, 714, 221, 723)  TRIBUTAÇÃO
# GlyphLessFont IRect(256, 714, 286, 723) SIMPLES
# GlyphLessFont IRect(285, 714, 324, 723)  NACIONAL
# GlyphLessFont IRect(367, 714, 390, 723) LOCAL
# GlyphLessFont IRect(389, 714, 435, 723)  PRESTAÇÃO
# GlyphLessFont IRect(480, 714, 503, 723) LOCAL
# GlyphLessFont IRect(502, 714, 546, 723)  INCIDÊNCIA
# GlyphLessFont IRect(385, 724, 417, 732) SERVIÇO
# GlyphLessFont IRect(63, 732, 96, 740) EXIGÍVEL
# GlyphLessFont IRect(151, 732, 186, 740) Sociedade
# GlyphLessFont IRect(185, 732, 217, 740)  Limitada
# GlyphLessFont IRect(283, 732, 296, 740) Não
# GlyphLessFont IRect(354, 732, 370, 740) SAO
# GlyphLessFont IRect(369, 732, 396, 740)  PEDRO
# GlyphLessFont IRect(395, 732, 409, 740)  DA
# GlyphLessFont IRect(408, 732, 447, 740)  ALDEIA/RJ
# GlyphLessFont IRect(489, 732, 536, 740) MESQUITA/RJ
# GlyphLessFont IRect(27, 748, 78, 760) Observação:
# GlyphLessFont IRect(77, 748, 96, 760)  LEI
# GlyphLessFont IRect(95, 748, 112, 760)  DA
# GlyphLessFont IRect(111, 748, 190, 760)  TRANSPARÊNCIA
# GlyphLessFont IRect(189, 748, 225, 760)  FISCAL
# GlyphLessFont IRect(224, 748, 242, 760)  NR.
# GlyphLessFont IRect(241, 748, 275, 760)  12.741,
# GlyphLessFont IRect(274, 748, 290, 760)  DE
# GlyphLessFont IRect(289, 748, 297, 760)  8
# GlyphLessFont IRect(296, 748, 313, 760)  DE
# GlyphLessFont IRect(312, 748, 366, 760)  DEZEMBRO
# GlyphLessFont IRect(365, 748, 381, 760)  DE
# GlyphLessFont IRect(380, 748, 406, 760)  2012.

# %% [markdown]
# ## Partial OCR
# Let's see what a **_partial OCR_** can do for us.
#
# A partial OCR `TextPage` internally stores text in the following sequence:
# 1. Normal text
# 2. OCR text from images in the same sequence as the page displays those images
#
# So we better use the `sort` parameter of text extraction.

# %%
partial_tp = page.get_textpage_ocr(flags=0, full=False, language='por', tessdata="C:\\Program Files\\Tesseract-OCR\\tessdata")

# look at the result
print(page.get_text(textpage=partial_tp, sort=True))  # sort by vertical, then horizontal
# Out:
# Número da Nota:
# PREFEITURA MUNICIPAL DE MESQUITA
# 2023173
# Competência:
# JULHO/2023
# SECRETARIA MUNICIPAL DE FAZENDA
# Data e Hora de Emisssão:
# 01/08/2023 03:32:41
# NOTA FISCAL DE SERVIÇO ELETRÔNICA - NFS-e
# RPS Nº: 1386 SÉRIE: 1 | EMISSÃO: 01/08/2023
# Código de Verificação:
# C64B104C7
# PRESTADOR DE SERVIÇOS
# CPF/CNPJ:
# Inscrição Municipal:
# 15.064.270/0001-33
# 5000545
# Telefone:
# Inscrição Estadual:
# (21) 3848-0080
# Nome/Razão Social:
# MODERNIZACAO PUBLICA E INFORMATICA LTDA
# 0 Pública |
# Nome Fantasia: Modernização Pública
# Endereço:
# RUA PREFEITO JOSE MONTES PAIXAO, 1708 SOBRADO CENTRO MESQUITA/RJ CEP: 26553-161
# E-mail:
# vm.direcao@yahoo.com.br
# TOMADOR DE SERVIÇOS
# CPF/CNPJ:
# Inscrição Municipal:
# 28.909.604/0001-74
# Telefone:
# Inscrição Estadual:
# Nome/Razão Social:
# PREF.MUN.DE SAO PEDRO DA ALDEIA
# Endereço:
# Rua Marques da Cruz, 61  CENTRO SAO PEDRO DA ALDEIA/RJ/RJ CEP: 28941-086
# E-mail:
# DISCRIMINAÇÃO DOS SERVIÇOS
# CESSAO DE LICENCIAMENTO DE USO DE SOLUCAO PARA SISTEMA INTEGRADO DE GESTAO PUBLICA CONTRATO  94/2022, PR
# OCESSO 6699/2022 NOTA FISCAL REFERENTE AO MES 07/2023
# -  CREDITAR NO BANCO BRADESCO AG 6615 C/C 12311-0 OU BANCO DO BRASIL AG 1253-X C/C 125016-7 OU
# PIX: CNPJ 15.064.270/0001-33
# VALOR TOTAL DA NOTA:
# R$ 206.549,00
# CNAE - 6202300 - DESENVOLVIMENTO E LICENCIAMENTO DE PROGRAMAS DE COMPUTADOR CUSTOMIZÁVEIS
# Item da Lista de Serviços -
# Licenciamento ou cessão de direito de uso de programas de computação.
# 1.05
# VALOR SERVIÇOS: VALOR
# DESC. INCOND.:
# BASE DE
# ALÍQUOTA:
# VALOR ISS:
# VALOR ISS
# DESC. COND.:
# DEDUÇÃO:
# CÁLCULO:
# RETIDO:
# R$ 206.549,00
# R$ 0,00
# R$ 0,00
# R$ 206.549,00
# 2,00 %
# R$ 4.130,98
# R$ 0,00
# R$ 0,00
# VALOR COFINS:
# VALOR IR:
# VALOR INSS:
# VALOR CSLL:
# OUTRAS RETENÇÕES:
# VALOR LÍQUIDO:
# VALOR PIS:
# R$ 0,00
# R$ 0,00
# R$ 0,00
# R$ 3.098,23
# R$ 0,00
# R$ 0,00
# R$ 203.450,77
# DADOS COMPLEMENTARES
# OUTRAS INFORMAÇÕES/CRÍTICAS
# EXIGIBILIDADE ISS
# LOCAL PRESTAÇÃO
# REGIME TRIBUTAÇÃO
# SIMPLES NACIONAL
# LOCAL INCIDÊNCIA
# SERVIÇO
# EXIGÍVEL
# MESQUITA/RJ
# Sociedade Limitada
# Não
# SAO PEDRO DA ALDEIA/RJ
# Observação:  LEI DA TRANSPARÊNCIA FISCAL NR. 12.741, DE 8 DE DEZEMBRO DE 2012.

# %% [markdown]
# This is very much better. Looking again at span details:

# %%
for block in page.get_text("dict", textpage=partial_tp, sort=True)["blocks"]:
    for line in block["lines"]:
        for span in line["spans"]:
            bbox = fitz.Rect(span["bbox"]).irect  # just to make it short
            print( span["font"], bbox, span["text"])
# Out:
# Arial IRect(489, 37, 566, 51) Número da Nota:
# Arial,Bold IRect(117, 55, 352, 72) PREFEITURA MUNICIPAL DE MESQUITA
# Arial,Bold IRect(526, 50, 566, 65) 2023173
# Arial IRect(516, 61, 566, 73) Competência:
# Arial,Bold IRect(518, 73, 566, 85) JULHO/2023
# Arial,Bold IRect(158, 73, 311, 85) SECRETARIA MUNICIPAL DE FAZENDA
# Arial IRect(472, 81, 566, 93) Data e Hora de Emisssão:
# Arial,Bold IRect(491, 93, 566, 105) 01/08/2023 03:32:41
# Arial,Bold IRect(139, 88, 330, 100) NOTA FISCAL DE SERVIÇO ELETRÔNICA - NFS-e
# Arial,Bold IRect(147, 102, 322, 114) RPS Nº: 1386 SÉRIE: 1 | EMISSÃO: 01/08/2023
# Arial IRect(485, 106, 566, 118) Código de Verificação:
# Arial,Bold IRect(521, 118, 566, 130) C64B104C7
# Arial,Bold IRect(217, 134, 378, 152) PRESTADOR DE SERVIÇOS
# Arial IRect(27, 155, 74, 169) CPF/CNPJ:
# Arial IRect(282, 155, 362, 169) Inscrição Municipal:
# Arial,Bold IRect(34, 166, 116, 180) 15.064.270/0001-33
# Arial,Bold IRect(290, 166, 326, 180) 5000545
# Arial IRect(27, 178, 65, 191) Telefone:
# Arial IRect(282, 178, 359, 191) Inscrição Estadual:
# Arial,Bold IRect(34, 189, 97, 202) (21) 3848-0080
# Arial IRect(27, 200, 110, 214) Nome/Razão Social:
# Arial,Bold IRect(34, 211, 252, 225) MODERNIZACAO PUBLICA E INFORMATICA LTDA
# GlyphLessFont IRect(488, 235, 495, 241) 0
# GlyphLessFont IRect(495, 165, 551, 246)  Pública
# GlyphLessFont IRect(550, 170, 561, 246)  |
# Arial IRect(27, 223, 91, 236) Nome Fantasia:
# Arial,Bold IRect(90, 223, 190, 237)  Modernização Pública
# Arial IRect(27, 236, 69, 249) Endereço:
# Arial,Bold IRect(34, 247, 454, 260) RUA PREFEITO JOSE MONTES PAIXAO, 1708 SOBRADO CENTRO MESQUITA/RJ CEP: 26553-161
# Arial IRect(27, 258, 55, 271) E-mail:
# Arial,Bold IRect(34, 269, 150, 282) vm.direcao@yahoo.com.br
# Arial,Bold IRect(223, 288, 372, 306) TOMADOR DE SERVIÇOS
# Arial IRect(27, 309, 74, 322) CPF/CNPJ:
# Arial IRect(282, 309, 362, 322) Inscrição Municipal:
# Arial,Bold IRect(34, 320, 116, 333) 28.909.604/0001-74
# Arial IRect(27, 332, 65, 345) Telefone:
# Arial IRect(282, 332, 359, 345) Inscrição Estadual:
# Arial IRect(27, 354, 110, 367) Nome/Razão Social:
# Arial,Bold IRect(34, 365, 205, 378) PREF.MUN.DE SAO PEDRO DA ALDEIA
# Arial IRect(27, 377, 69, 390) Endereço:
# Arial,Bold IRect(34, 388, 391, 401) Rua Marques da Cruz, 61  CENTRO SAO PEDRO DA ALDEIA/RJ/RJ CEP: 28941-086
# Arial IRect(27, 399, 55, 412) E-mail:
# Arial,Bold IRect(201, 416, 394, 433) DISCRIMINAÇÃO DOS SERVIÇOS
# Arial IRect(27, 440, 522, 452) CESSAO DE LICENCIAMENTO DE USO DE SOLUCAO PARA SISTEMA INTEGRADO DE GESTAO PUBLICA CONTRATO  94/2022, PR
# Arial IRect(27, 449, 272, 461) OCESSO 6699/2022 NOTA FISCAL REFERENTE AO MES 07/2023
# Arial IRect(27, 458, 449, 470) -  CREDITAR NO BANCO BRADESCO AG 6615 C/C 12311-0 OU BANCO DO BRASIL AG 1253-X C/C 125016-7 OU
# Arial IRect(27, 467, 140, 479) PIX: CNPJ 15.064.270/0001-33
# Arial,Bold IRect(176, 524, 324, 542) VALOR TOTAL DA NOTA:
# Arial,Bold IRect(325, 524, 405, 542) R$ 206.549,00
# Arial IRect(27, 546, 459, 558) CNAE - 6202300 - DESENVOLVIMENTO E LICENCIAMENTO DE PROGRAMAS DE COMPUTADOR CUSTOMIZÁVEIS
# Arial IRect(27, 558, 122, 570) Item da Lista de Serviços -
# Arial IRect(143, 558, 406, 570) Licenciamento ou cessão de direito de uso de programas de computação.
# Arial IRect(123, 558, 140, 570) 1.05
# Arial IRect(84, 580, 176, 591) VALOR SERVIÇOS: VALOR
# Arial IRect(213, 580, 268, 591) DESC. INCOND.:
# Arial IRect(273, 580, 305, 591) BASE DE
# Arial IRect(336, 580, 374, 591) ALÍQUOTA:
# Arial IRect(396, 580, 436, 591) VALOR ISS:
# Arial IRect(457, 580, 495, 591) VALOR ISS
# Arial IRect(516, 580, 564, 591) DESC. COND.:
# Arial IRect(152, 591, 190, 601) DEDUÇÃO:
# Arial IRect(273, 591, 309, 601) CÁLCULO:
# Arial IRect(457, 591, 486, 601) RETIDO:
# Arial,Bold IRect(84, 601, 130, 612) R$ 206.549,00
# Arial,Bold IRect(152, 601, 177, 612) R$ 0,00
# Arial,Bold IRect(213, 601, 238, 612) R$ 0,00
# Arial,Bold IRect(273, 601, 320, 612) R$ 206.549,00
# Arial,Bold IRect(336, 601, 358, 612) 2,00 %
# Arial,Bold IRect(396, 601, 435, 612) R$ 4.130,98
# Arial,Bold IRect(457, 601, 483, 612) R$ 0,00
# Arial,Bold IRect(516, 601, 541, 612) R$ 0,00
# Arial IRect(152, 619, 207, 629) VALOR COFINS:
# Arial IRect(213, 619, 248, 629) VALOR IR:
# Arial IRect(273, 619, 318, 629) VALOR INSS:
# Arial IRect(336, 619, 382, 629) VALOR CSLL:
# Arial IRect(396, 619, 474, 629) OUTRAS RETENÇÕES:
# Arial IRect(516, 619, 573, 629) VALOR LÍQUIDO:
# Arial IRect(84, 618, 129, 630) VALOR PIS:
# Arial,Bold IRect(84, 630, 109, 641) R$ 0,00
# Arial,Bold IRect(273, 630, 299, 641) R$ 0,00
# Arial,Bold IRect(152, 630, 177, 641) R$ 0,00
# Arial,Bold IRect(213, 630, 252, 641) R$ 3.098,23
# Arial,Bold IRect(336, 630, 361, 641) R$ 0,00
# Arial,Bold IRect(396, 630, 422, 641) R$ 0,00
# Arial,Bold IRect(516, 630, 562, 641) R$ 203.450,77
# Arial,Bold IRect(214, 647, 381, 664) DADOS COMPLEMENTARES
# Arial,Bold IRect(195, 689, 400, 707) OUTRAS INFORMAÇÕES/CRÍTICAS
# Arial IRect(47, 713, 112, 724) EXIGIBILIDADE ISS
# Arial IRect(366, 713, 436, 724) LOCAL PRESTAÇÃO
# Arial IRect(146, 713, 222, 724) REGIME TRIBUTAÇÃO
# Arial IRect(255, 713, 325, 724) SIMPLES NACIONAL
# Arial IRect(480, 713, 546, 724) LOCAL INCIDÊNCIA
# Arial IRect(385, 722, 417, 733) SERVIÇO
# Arial,Bold IRect(63, 731, 96, 742) EXIGÍVEL
# Arial,Bold IRect(489, 731, 537, 742) MESQUITA/RJ
# Arial,Bold IRect(151, 731, 218, 742) Sociedade Limitada
# Arial,Bold IRect(283, 731, 297, 742) Não
# Arial,Bold IRect(354, 731, 448, 742) SAO PEDRO DA ALDEIA/RJ
# Arial IRect(27, 747, 407, 760) Observação:  LEI DA TRANSPARÊNCIA FISCAL NR. 12.741, DE 8 DE DEZEMBRO DE 2012.

# %% [markdown]
# As mentioned, normal text is **_not OCRed_** in this case, so keeps its own font, fontsize, position information, etc. Whereas OCRed text appears with Tesseract's `GlyphLessFont`.
#
# > During its internal processing, MuPDF treats every word returned by Tesseract as a separate text span.

# %% [markdown]
# ## Performance
# We mentioned in the beginning, that the OCR work is done during `TextPage` creation. Already without OCR, textpage creation is the most time consuming part of text processing.
#
# Creating OCR textpages may easily take 100 to several thousand times longer. It therefore by all means should happen only once per document page.
#
# The new `textpage` parameter in all text processing methods allows referring to an existing textpage and will suppress creating another one.
#
# Here are some performance comparisons for our example page:

# %%
# normal text extraction - no OCR
# %timeit page.get_textpage(flags=0)  # suppress image extraction
# Out:
# 454 µs ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# full page OCR
# %timeit page.get_textpage_ocr(flags=0, full=True, dpi=300, language='por', tessdata="C:\\Program Files\\Tesseract-OCR\\tessdata")
# Out:
# 1.02 s ± 16.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# partial OCR
# %timeit page.get_textpage_ocr(flags=0, full=False, language='por', tessdata="C:\\Program Files\\Tesseract-OCR\\tessdata")
# Out:
# 20.8 ms ± 1.02 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# The above numbers illustrate that OCRing a page is time consuming! Creating an OCR `TextPage` may be several thousand times slower.
#
# Once you **_have_** the textpage however, **_processing_** its text is as fast as it ever was:

# %%
# normal textpage
normal_tp = page.get_textpage(flags=0)
# %timeit page.get_text(textpage=normal_tp)
# Out:
# 30.7 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# full page OCR
# %timeit page.get_text(textpage=full_tp)
# Out:
# 30.4 µs ± 288 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# partial page OCR
# %timeit page.get_text(textpage=partial_tp)
# Out:
# 29.8 µs ± 553 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
from operator import itemgetter
from itertools import groupby
import fitz

# %%
# ==============================================================================
# Function ParseTab - parse a document table into a Python list of lists
# ==============================================================================
def ParseTab(page, bbox, columns=None):
    """Returns the parsed table of a page in a PDF / (open) XPS / EPUB document.
    Parameters:
    page: fitz.Page object
    bbox: containing rectangle, list of numbers [xmin, ymin, xmax, ymax]
    columns: optional list of column coordinates. If None, columns are generated
    Returns the parsed table as a list of lists of strings.
    The number of rows is determined automatically
    from parsing the specified rectangle.
    """
    tab_rect = fitz.Rect(bbox).irect
    xmin, ymin, xmax, ymax = tuple(tab_rect)

    if tab_rect.is_empty or tab_rect.is_infinite:
        print("Warning: incorrect rectangle coordinates!")
        return []

    if type(columns) is not list or columns == []:
        coltab = [tab_rect.x0, tab_rect.x1]
    else:
        coltab = sorted(columns)

    if xmin < min(coltab):
        coltab.insert(0, xmin)
    if xmax > coltab[-1]:
        coltab.append(xmax)

    words = page.get_text("words")

    if words == []:
        print("Warning: page contains no text")
        return []

    alltxt = []

    # get words contained in table rectangle and distribute them into columns
    for w in words:
        ir = fitz.Rect(w[:4]).irect  # word rectangle
        if ir in tab_rect:
            cnr = 0  # column index
            for i in range(1, len(coltab)):  # loop over column coordinates
                if ir.x0 < coltab[i]:  # word start left of column border
                    cnr = i - 1
                    break
            alltxt.append([ir.x0, ir.y0, ir.x1, cnr, w[4]])

    if alltxt == []:
        print("Warning: no text found in rectangle!")
        return []

    alltxt.sort(key=itemgetter(1))  # sort words vertically

    # create the table / matrix
    spantab = []  # the output matrix

    for y, zeile in groupby(alltxt, itemgetter(1)):
        schema = [""] * (len(coltab) - 1)
        for c, words in groupby(zeile, itemgetter(3)):
            entry = " ".join([w[4] for w in words])
            schema[c] = entry
        spantab.append(schema)

    return spantab

# %%
import fitz

# %%
table = ParseTab(doc, 20, [0, 0, 500, 700])

# %%
doc = fitz.Document(r".\PyMuPDF_examples\272519EC-959B-4460-BBE6-D80D272B9ACD.PDF")

# %%
table = ParseTab(doc, [0, 0, 5, 600])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 table = ParseTab(doc, [0, 0, 5, 600])
#
# Cell In[3], line 31, in ParseTab(page, bbox, columns)
#      28 if xmax > coltab[-1]:
#      29     coltab.append(xmax)
# ---> 31 words = page.get_text("words")
#      33 if words == []:
#      34     print("Warning: page contains no text")
#
# AttributeError: 'Document' object has no attribute 'get_text'
